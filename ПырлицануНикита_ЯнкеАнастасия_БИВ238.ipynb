# %%
from dotenv import load_dotenv
import os

load_dotenv()

token = os.environ.get('token')
GigaChatKey = os.environ.get('GigaChatKey')

# %%
# Requirements
# !pip install aiogram aiosqlite apscheduler
# !pip install nest_asyncio
# !pip install langchain-gigachat langchain-community
import nest_asyncio
nest_asyncio.apply()
# Out:
# Requirement already satisfied: aiogram in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: aiosqlite in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (0.18.0)
# Requirement already satisfied: apscheduler in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (3.11.0)
# Requirement already satisfied: aiofiles~=23.2.1 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiogram) (23.2.1)
# Requirement already satisfied: aiohttp~=3.9.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiogram) (3.9.5)
# Requirement already satisfied: certifi>=2023.7.22 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiogram) (2024.2.2)
# Requirement already satisfied: magic-filter<1.1,>=1.0.12 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiogram) (1.0.12)
# Requirement already satisfied: pydantic<2.8,>=2.4.1 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiogram) (2.7.4)
# Requirement already satisfied: typing-extensions<=5.0,>=4.7.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiogram) (4.12.2)
# Requirement already satisfied: tzlocal>=3.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from apscheduler) (5.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.9.0->aiogram) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.9.0->aiogram) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.9.0->aiogram) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.9.0->aiogram) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.9.0->aiogram) (1.9.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from pydantic<2.8,>=2.4.1->aiogram) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from pydantic<2.8,>=2.4.1->aiogram) (2.18.4)
# Requirement already satisfied: idna>=2.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp~=3.9.0->aiogram) (3.7)
# Requirement already satisfied: nest_asyncio in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (1.5.6)
# Requirement already satisfied: langchain-gigachat in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: langchain-community in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (0.3.14)
# Requirement already satisfied: gigachat<0.2.0,>=0.1.36 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-gigachat) (0.1.37)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-gigachat) (0.3.29)
# Requirement already satisfied: types-requests<3.0,>=2.32 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-gigachat) (2.32.0.20241016)
# Requirement already satisfied: PyYAML>=5.3 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (1.4.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.14 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.3.14)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (0.2.10)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (1.24.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-community) (8.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpx<=0.27.2 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from gigachat<0.2.0,>=0.1.36->langchain-gigachat) (0.27.2)
# Requirement already satisfied: pydantic>=1 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from gigachat<0.2.0,>=0.1.36->langchain-gigachat) (2.7.4)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.14->langchain-community) (0.3.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langchain-core<0.4,>=0.3->langchain-gigachat) (4.12.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (3.10.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2024.2.2)
# Requirement already satisfied: anyio in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from httpx<=0.27.2->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (3.5.0)
# Requirement already satisfied: httpcore==1.* in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from httpx<=0.27.2->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (1.0.7)
# Requirement already satisfied: sniffio in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from httpx<=0.27.2->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<=0.27.2->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-gigachat) (2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from pydantic>=1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from pydantic>=1->gigachat<0.2.0,>=0.1.36->langchain-gigachat) (2.18.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/nikitapyrlicanu/anaconda3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %%
#Пример формирования диалога с GigaChat
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_gigachat.chat_models import GigaChat

llm = GigaChat(
    credentials=GigaChatKey,
    scope="GIGACHAT_API_PERS",
    model="GigaChat",
    verify_ssl_certs=False, # Отключает проверку наличия сертификатов НУЦ Минцифры
    streaming=False,
)


system_messages = [
    SystemMessage(
        content="Ты профессианальный тренер покемонов, который отлично разрирается в навыках любого покемона. Твоя задача - помагать со всеми приходящими вопросами от тренеров-новичков."
    )
]

user_messages = {}

pokemon_predict_template = """Я отправлю тебе моих покемонов, покемонов соперника и их уровни. Опредили тип этих покемонов исходя из их названия, и твоих знаний о них. Если лучшего варианта нет, скажи об этом, и очень кратко приведи типы покемонов, которые мне нужны, но все равно ты обязан предложить хотя бы какую-нибудь комбинацию именно моих покемонов, которыми я сейчас обладаю, и не предлагать покемонов, которых у меня нет.
Все мои покемоны: {}. Далеее идут покемоны противника
Покемоны противника: {}.
Твоя задача - предложить лучший вариант комбинации моих покемонов, которые буду сражаться против покемонов противника. Если покемон написан несколько раз - значит у меня их несколько. 
Также ты обязан задать мне ровно один дополнительный вопрос, которые поможет тебе улучшить ответ.
"""

async def start_pokemon_prediction(user_id, team_pokemons, enemy_pokemons):
    print(team_pokemons)
    team_pokemons_str = ", ".join(map(lambda x: f"{x[2]}: lvl{x[3]}", team_pokemons))
    enemy_pokemons_str = ", ".join(map(lambda x: f"{x[0]}: lvl{x[1]}", enemy_pokemons))

    msg = pokemon_predict_template.format(team_pokemons_str, enemy_pokemons_str)
    llm_messages = system_messages + user_messages.get(user_id, [])
    llm_messages.append(HumanMessage(msg))

    print(llm_messages)

    response = await llm.ainvoke(llm_messages)
    llm_messages.append(response)
    user_messages[user_id] = llm_messages

    print(response)
    return response


async def end_pokemon_prediction(user_id, text):
    msg = user_messages.get(user_id, None)

    if not msg:
        return "Something went wrong"
    
    del user_messages[user_id]

    msg.append(HumanMessage(text))
    response = await llm.ainvoke(msg)

    return response

# %%
from aiogram import Bot, Dispatcher
from aiogram.client.default import DefaultBotProperties
from aiogram.enums import ParseMode
from aiogram.fsm.storage.memory import MemoryStorage
from aiogram import Router, F
from aiogram.filters import CommandStart, Command, CommandObject
from aiogram.types import Message
from aiogram.types import KeyboardButton, ReplyKeyboardMarkup, KeyboardButtonPollType
from aiogram.utils.keyboard import ReplyKeyboardBuilder
from aiogram.types import InlineKeyboardMarkup, InlineKeyboardButton, WebAppInfo
from aiogram.utils.keyboard import InlineKeyboardBuilder
from aiogram.types import BotCommand, BotCommandScopeDefault
from aiogram.types import CallbackQuery
from aiogram.utils.chat_action import ChatActionSender
from aiogram.types import ReplyKeyboardRemove
from aiogram.fsm.context import FSMContext
from aiogram.fsm.state import State, StatesGroup
from typing import Any, Awaitable, Callable, Dict
from aiogram import BaseMiddleware
from aiogram.types import TelegramObject
from html import escape

import datetime
import asyncio
import logging
import aiosqlite

from apscheduler.schedulers.asyncio import AsyncIOScheduler


class RegCheckMiddleware(BaseMiddleware):
    async def __call__(
        self,
        handler: Callable[[TelegramObject, Dict[str, Any]], Awaitable[Any]],
        event: TelegramObject,
        data: Dict[str, Any]
    ) -> Any:

        print(f"CHECK! {event.from_user.id}")
        if not await dbcontroller.get_user(event.from_user.id):
            print("UNREGISTERED USER!")
            await event.answer("Для начала используйте /start, чтобы зарегестрироватся.")
            return

        result = await handler(event, data)

        return result
    

class LoggerMiddleware(BaseMiddleware):
    async def __call__(self, handler, event: Message, data: dict):
        user_id = event.from_user.id
        username = event.from_user.username or "Unknown"
        action = event.text
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        with open("logs.csv", "a") as log_file:
            log_file.write(f"{timestamp},{user_id},{username},{action}\n")

        return await handler(event, data)


class Form(StatesGroup):
    nickname = State()
    team = State()

class FightStates(StatesGroup):
    enemy_pokemons = State()

class ClearStates(StatesGroup):
    clear_my_team = State()
    delete_pokemon = State()

class LLMStates(StatesGroup):
    strategy_question = State()


logging.basicConfig(force=True, level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

bot = Bot(token=token, default=DefaultBotProperties(parse_mode=ParseMode.HTML))
dp = Dispatcher(storage=MemoryStorage())

registered_router = Router(name="registered")
start_router = Router(name=__name__)


class DBController:
    @staticmethod
    async def add_user(id, name):
        async with aiosqlite.connect("users.db") as db:
            await db.execute("INSERT INTO users VALUES (?, ?)", (id, name))
            await db.commit()
    @staticmethod
    async def get_user(id):
        async with aiosqlite.connect("users.db") as db:
            async with db.execute("SELECT * FROM users WHERE id = ?", (id,)) as cursor:
                return await cursor.fetchone()
    @staticmethod
    async def get_user_by_nickname(name: str):
        async with aiosqlite.connect("users.db") as db:
            async with db.execute("SELECT * FROM users WHERE nickname = ?", (name,)) as cursor:
              return await cursor.fetchone()
    @staticmethod
    async def del_user(id):
      async with aiosqlite.connect("users.db") as db:
        await db.execute("DELETE FROM users WHERE id = ?", (id,))
        await db.commit()
    @staticmethod
    async def show_db():
        async with aiosqlite.connect('users.db') as db:
            async with db.execute("SELECT * FROM users") as cursor:
                async for row in cursor:
                    print(row)
    @staticmethod
    async def is_real_pokemon(name):
        async with aiosqlite.connect("users.db") as db:
            async with db.execute("SELECT * FROM pokemons WHERE name = ?", (name,)) as cursor:
              return await cursor.fetchone() is not None
    @staticmethod
    async def get_all_pokemons():
        async with aiosqlite.connect("users.db") as db:
            async with db.execute("SELECT * FROM pokemons") as cursor:
              return await cursor.fetchall()

    @staticmethod
    async def get_user_pokemons(id):
        print(id)
        async with aiosqlite.connect("users.db") as db:
            async with db.execute("SELECT * FROM user_pokemons WHERE user_id=?", (id,)) as cursor:
              return await cursor.fetchall() or []
                
    @staticmethod
    async def add_pokemon(id, pokemon_name, pokemon_lvl):
        async with aiosqlite.connect("users.db") as db:
            await db.execute("INSERT INTO user_pokemons VALUES (NULL, ?, ?, ?)", (id, pokemon_name, pokemon_lvl))
            await db.commit()

    @staticmethod
    async def add_real_pokemon(pokemon_name):
        async with aiosqlite.connect("users.db") as db:
            await db.execute("INSERT INTO pokemons VALUES (?)", (pokemon_name,))
            await db.commit()

    @staticmethod
    async def delete_user_pokemons(user_id):
        async with aiosqlite.connect("users.db") as db:
            await db.execute("DELETE FROM user_pokemons WHERE user_id=?", (user_id,))
            await db.commit()

    @staticmethod
    async def delete_user_pokemon(user_id, pokemon_name, pokemon_lvl):
        async with aiosqlite.connect("users.db") as db:
            await db.execute("DELETE FROM user_pokemons WHERE pokemon_id = "
                             "(SELECT MIN(pokemon_id) FROM user_pokemons WHERE user_id = ? AND pokemon_name=? AND pokemon_lvl=?)", (user_id, pokemon_name, pokemon_lvl))
            await db.commit()



dbcontroller = DBController()


@start_router.message(CommandStart())
async def cmd_start(message: Message, state: FSMContext):
    usr = await dbcontroller.get_user(message.from_user.id)

    if not usr:
        await message.answer(f'Привет, {message.from_user.last_name} {message.from_user.first_name}! Введите свой новый ник')
        await state.set_state(Form.nickname)
        return

    await message.answer(f"Привет, {usr[1]}. Используйте /help для помощи, или /, чтобы увидеть доступные команды.")
    return


@start_router.message(Command("help"))
async def help(message: Message):
    is_reg = bool(await dbcontroller.get_user(message.from_user.id))

    if not is_reg:
        await message.answer(f"/start - регистрация")
        return
    
    await message.answer(f"/strategy - анализ команды тренера и противника с последующими предложениями")


@dp.message(Form.nickname)
async def add_name(message: Message, state: FSMContext):
    print(message.text)
    if await dbcontroller.get_user_by_nickname(message.text):
        await message.answer(f"Ник занят. Пожалуйста, выберите другой.")
        return
    
    await state.update_data(nickname=message.text)
    await state.set_state(None)

    await dbcontroller.add_user(message.from_user.id, message.text)

    await message.answer(f"Теперь ваш ник {message.text}")


@dp.message(Command("real_pokemons"))
async def real_pokemons(message: Message):
    pkms = await dbcontroller.get_all_pokemons()
    print(pkms)
    msg = "\n".join(map(lambda x: x[0], pkms))

    if not msg:
        await message.answer("EMPTY")
        return
    
    await message.answer(msg)

@dp.message(Command("add_real_pokemon"))
async def real_pokemons(message: Message):
    name = message.text.split()[1]

    await dbcontroller.add_real_pokemon(name)
    await message.answer(f"Покемон {name} добавлен")


@registered_router.message(Command("clear_my_team"))
async def clear_my_team(message: Message, state: FSMContext):
    await dbcontroller.delete_user_pokemons(message.from_user.id)
    await message.answer("Your team is cleared")


@registered_router.message(LLMStates.strategy_question)
async def additional_strategy__question(message: Message, state: FSMContext):
    response = await end_pokemon_prediction(message.from_user.id, message.text)
    await message.answer(response.content)
    await message.answer("Диалог с GigaChat окончен.")
    await state.clear()
    await state.set_state(None)

# @start_router.callback_query(F.data == 'team_end')
@registered_router.message(Form.team)
async def add_team(message: Message, state: FSMContext):
    if isinstance(message, CallbackQuery) or message.text.lower() == "конец":
        await message.answer(f"Добавление покемонов закончено", reply_markup=ReplyKeyboardRemove())
        await state.set_state(None)
        return
        
    if len(message.text.split()) != 2:
        await message.answer(f"Введите всех своих покемонов в формате: POKEMON_NAME POKEMON_LVL")
        return
        
    name, lvl = message.text.split()
    if not lvl.isdigit():
        await message.answer(f"Lvl должен быть числом")
        return

    if not (await dbcontroller.is_real_pokemon(name)):
        await message.answer(f"Это не настоящий покемон (или его нет в системе)!")
        return

    await dbcontroller.add_pokemon(message.from_user.id, name, lvl)

    builder = ReplyKeyboardBuilder()
    builder.button(text="Конец", callback_data="конец")

    await message.answer(f"В вашу команду успешно добавлен {name}: lvl{lvl}", reply_markup=builder.as_markup(one_time_keyboard=True))

@registered_router.message(Command("update_team"))
@registered_router.message(F.text == "Enter team")
async def enter_team(message: Message, state: FSMContext):
    await state.set_state(Form.team)
    await message.answer(f"Введите всех своих покемонов в формате: POKEMON_NAME POKEMON_LVL")

@registered_router.message(Command("myteam"))
async def my_team(message: Message):
    pkms = await dbcontroller.get_user_pokemons(message.from_user.id)

    print("ASD, ", pkms)
    msg = "\n".join(map(lambda x: f"{x[2]}: lvl {x[3]}", pkms))

    if not msg:
        await message.answer("Ваша команда пуста.")
        return
    
    await message.answer(msg)


@registered_router.message(Command("delete_pokemon"))
async def delete_pokemon(message: Message, state: FSMContext):
    await state.set_state(ClearStates.delete_pokemon)

    kb_but = []

    for p in await dbcontroller.get_user_pokemons(message.from_user.id):
        kb_but.append([InlineKeyboardButton(text=f"{p[2]}: lvl {p[3]}", callback_data=f"{p[2]} {p[3]}")])

    if not kb_but:
        await bot.send_message(message.from_user.id, "Ваша команда пуста.")
        await state.set_state(None)
        return False
    
    kb_but.append([InlineKeyboardButton(text="Конец", callback_data="end")])
    
    kb = InlineKeyboardMarkup(inline_keyboard=kb_but, one_time_keyboard=True)

    await bot.send_message(message.from_user.id, "Выберите покемона для удаления", reply_markup=kb)
    return True

@registered_router.callback_query(ClearStates.delete_pokemon)
async def delete_pokemon_query(callback_query: CallbackQuery, state: FSMContext):
    await bot.delete_message(callback_query.from_user.id, callback_query.message.message_id)
    if callback_query.data == "end":
        await callback_query.answer("Удаление покемонов закончено")
        await state.set_state(None)
        return

    pokemon_name, pokemon_level = callback_query.data.split()
    await dbcontroller.delete_user_pokemon(callback_query.from_user.id, pokemon_name, int(pokemon_level))

    await callback_query.message.answer(f"Покемон {pokemon_name}: lvl {pokemon_level} удален из вашей команды")

    if not await delete_pokemon(callback_query, state=state):
        await bot.delete_message(callback_query.from_user.id, callback_query.message.message_id)



@registered_router.message(Command("strategy"))
async def fight(message: Message, state: FSMContext):
    team_pokemons = await dbcontroller.get_user_pokemons(message.from_user.id)
    if not team_pokemons:
        await message.answer("Похоже, ваша команда пуста..")
        return
    
    await state.update_data(enemy_pokemons=[])
    await state.set_state(FightStates.enemy_pokemons)
    await message.answer("Введите покемонов из команды противника")

async def start_fight_prediction(message: Message, state: FSMContext, enemy_pokemons):
    team_pokemons = await dbcontroller.get_user_pokemons(message.from_user.id)
    if not team_pokemons:
        await message.answer("Похоже, ваша команда пуста..")
        return

    prediction = await start_pokemon_prediction(message.from_user.id, team_pokemons, enemy_pokemons)
    await state.set_state(LLMStates.strategy_question)

    await message.answer(prediction.content)

@registered_router.message(FightStates.enemy_pokemons)
async def fight_pokemons(message: Message, state: FSMContext):
    if isinstance(message, CallbackQuery) or message.text.lower() == "конец":
        await message.answer(f"Пожалуйста, подождите ответа от GigaChat.", reply_markup=ReplyKeyboardRemove())
        await state.set_state(None)
        await start_fight_prediction(message, state, enemy_pokemons=(await state.get_data())["enemy_pokemons"])
        return
        
    if len(message.text.split()) != 2:
        await message.answer(f"Введите в формате: POKEMON_NAME POKEMON_LVL")
        return
        
    name, lvl = message.text.split()
    if not lvl.isdigit():
        await message.answer(f"Lvl должен быть числом")
        return

    if not (await dbcontroller.is_real_pokemon(name)):
        await message.answer(f"Это не настоящий покемон (или его нет в системе)!")
        return

    enemy_pokemons = (await state.get_data())["enemy_pokemons"]
    enemy_pokemons.append((name, lvl))
    await state.update_data(enemy_pokemons=enemy_pokemons)

    builder = ReplyKeyboardBuilder()
    builder.button(text="Конец", callback_data="конец") 

    await message.answer(f"Добавлен покемон противника {name}: lvl{lvl}", reply_markup=builder.as_markup(one_time_keyboard=True))


@registered_router.message(F.text)
async def cmd_mes(message: Message):
    await message.answer(f"Это понимать я еще не научился")

async def send_msg(dp):
  async with aiosqlite.connect('users.db') as db:
    async with db.execute("SELECT * FROM users") as cursor:
      async for row in cursor:
        await bot.send_message(chat_id=row[0], text='Не забывайте обновлять информацию о своей команде!')

async def start_bot():
    commands = [BotCommand(command='start', description='Старт'),
                BotCommand(command='update_team', description='Заполнить команду покемонов'),
                BotCommand(command='myteam', description='Посмотреть моих покемонов'),
                BotCommand(command='clear_my_team', description='Очистить команду'),
                BotCommand(command='delete_pokemon', description='Удалить покемонов'),
                BotCommand(command='strategy', description='Анализ покемонов для составления стратегии'),
                BotCommand(command='real_pokemons', description='Список сущ. в сист. покемонов'),
                BotCommand(command='add_real_pokemon', description='Добавление в сист. покемонов'),
    ]
    await bot.set_my_commands(commands, BotCommandScopeDefault())

async def start_db():
    # Подключение к базе данных (если файл не существует, он будет создан)

    async with aiosqlite.connect('users.db') as db:
        await db.execute('DROP TABLE IF EXISTS users')
        await db.execute('DROP TABLE IF EXISTS user_pokemons')
        # Создание таблицы, если она не существует
        await db.execute('''
            CREATE TABLE IF NOT EXISTS users (
                id INTEGER PRIMARY KEY,
                nickname TEXT
            )
        ''')
        await db.execute('''
            CREATE TABLE IF NOT EXISTS pokemons (
                name TEXT PRIMARY KEY
            )
        ''')

        await db.execute('''
            CREATE TABLE IF NOT EXISTS user_pokemons (
                pokemon_id INTEGER PRIMARY KEY AUTOINCREMENT,
                user_id INT,
                pokemon_name TEXT,
                pokemon_lvl INT,
                FOREIGN KEY (user_id) REFERENCES users (id) ON DELETE CASCADE
            )
        ''')
        # Сохранение изменений
        await db.commit()

async def main(): #Основная асинхронная функция, которая будет запускаться при старте бота.
    scheduler = AsyncIOScheduler(timezone='Europe/Moscow')
    job = scheduler.add_job(send_msg, 'interval', seconds=500, args=(dp,))
    scheduler.start()
    
    registered_router.message.outer_middleware(RegCheckMiddleware())
    registered_router.message.middleware(LoggerMiddleware())
    start_router.message.middleware(LoggerMiddleware())
    
    dp.include_router(start_router)
    dp.include_router(registered_router) 
    dp.startup.register(start_bot)
    dp.startup.register(start_db)
    
    try:
      print("Бот запущен...")
      await bot.delete_webhook(drop_pending_updates=True)
      await dp.start_polling(bot, allowed_updates=dp.resolve_used_update_types()) # Запускаем бота в режиме опроса (polling). Бот начинает непрерывно запрашивать обновления с сервера Telegram и обрабатывать их
    finally:
      scheduler.remove_job(job.id)
      await bot.session.close()
      print("Бот остановлен")

asyncio.run(main())
# Out:
# 2025-01-19 16:58:53,726 - apscheduler.scheduler - INFO - Adding job tentatively -- it will be properly scheduled when the scheduler starts
# 2025-01-19 16:58:53,727 - apscheduler.scheduler - INFO - Added job "send_msg" to job store "default"
# 2025-01-19 16:58:53,727 - apscheduler.scheduler - INFO - Scheduler started
# Бот запущен...
# 2025-01-19 16:58:54,040 - aiogram.dispatcher - INFO - Start polling
# 2025-01-19 16:58:54,098 - aiogram.dispatcher - INFO - Run polling for bot @TestOGE8_bot id=5141660175 - 'PokemonStrategy'
# CHECK! 887383975
# UNREGISTERED USER!
# 2025-01-19 16:58:57,082 - aiogram.event - INFO - Update id=708829274 is handled. Duration 329 ms by bot id=5141660175
# 2025-01-19 17:07:13,729 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:15:33 MSK)" (scheduled at 2025-01-19 17:07:13.726491+03:00)
# 2025-01-19 17:07:13,743 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:15:33 MSK)" executed successfully
# 2025-01-19 17:20:00,245 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-19 17:20:00,246 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-19 17:20:11,572 - aiogram.dispatcher - INFO - Connection established (tryings = 1, bot id = 5141660175)
# 2025-01-19 17:26:28,347 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-19 17:26:28,348 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-19 17:26:39,727 - aiogram.dispatcher - INFO - Connection established (tryings = 1, bot id = 5141660175)
# 2025-01-19 17:27:43,696 - apscheduler.executors.default - WARNING - Run time of job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:32:13 MSK)" was missed by 0:03:49.969607
# 2025-01-19 17:32:13,732 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:40:33 MSK)" (scheduled at 2025-01-19 17:32:13.726491+03:00)
# 2025-01-19 17:32:13,743 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:40:33 MSK)" executed successfully
# 2025-01-19 17:40:33,735 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:48:53 MSK)" (scheduled at 2025-01-19 17:40:33.726491+03:00)
# 2025-01-19 17:40:33,745 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:48:53 MSK)" executed successfully
# 2025-01-19 17:48:53,734 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:57:13 MSK)" (scheduled at 2025-01-19 17:48:53.726491+03:00)
# 2025-01-19 17:48:53,740 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 17:57:13 MSK)" executed successfully
# 2025-01-19 17:57:13,735 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:05:33 MSK)" (scheduled at 2025-01-19 17:57:13.726491+03:00)
# 2025-01-19 17:57:13,741 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:05:33 MSK)" executed successfully
# 2025-01-19 18:05:33,735 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:13:53 MSK)" (scheduled at 2025-01-19 18:05:33.726491+03:00)
# 2025-01-19 18:05:33,743 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:13:53 MSK)" executed successfully
# 2025-01-19 18:13:53,729 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:22:13 MSK)" (scheduled at 2025-01-19 18:13:53.726491+03:00)
# 2025-01-19 18:13:53,734 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:22:13 MSK)" executed successfully
# 2025-01-19 18:22:13,732 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:30:33 MSK)" (scheduled at 2025-01-19 18:22:13.726491+03:00)
# 2025-01-19 18:22:13,738 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:30:33 MSK)" executed successfully
# 2025-01-19 18:30:33,732 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:38:53 MSK)" (scheduled at 2025-01-19 18:30:33.726491+03:00)
# 2025-01-19 18:30:33,736 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:38:53 MSK)" executed successfully
# 2025-01-19 18:38:53,731 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:47:13 MSK)" (scheduled at 2025-01-19 18:38:53.726491+03:00)
# 2025-01-19 18:38:53,737 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:47:13 MSK)" executed successfully
# 2025-01-19 18:47:13,729 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:55:33 MSK)" (scheduled at 2025-01-19 18:47:13.726491+03:00)
# 2025-01-19 18:47:13,734 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 18:55:33 MSK)" executed successfully
# 2025-01-19 18:55:33,728 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:03:53 MSK)" (scheduled at 2025-01-19 18:55:33.726491+03:00)
# 2025-01-19 18:55:33,731 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:03:53 MSK)" executed successfully
# 2025-01-19 19:03:53,728 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:12:13 MSK)" (scheduled at 2025-01-19 19:03:53.726491+03:00)
# 2025-01-19 19:03:53,732 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:12:13 MSK)" executed successfully
# 2025-01-19 19:12:13,755 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:20:33 MSK)" (scheduled at 2025-01-19 19:12:13.726491+03:00)
# 2025-01-19 19:12:13,762 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:20:33 MSK)" executed successfully
# 2025-01-19 19:20:33,732 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:28:53 MSK)" (scheduled at 2025-01-19 19:20:33.726491+03:00)
# 2025-01-19 19:20:33,739 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:28:53 MSK)" executed successfully
# 2025-01-19 19:24:49,579 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [Connect call failed ('149.154.167.220', 443)]
# 2025-01-19 19:24:49,580 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-19 19:25:00,799 - aiogram.dispatcher - INFO - Connection established (tryings = 1, bot id = 5141660175)
# 2025-01-19 19:28:53,730 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:37:13 MSK)" (scheduled at 2025-01-19 19:28:53.726491+03:00)
# 2025-01-19 19:28:53,735 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:37:13 MSK)" executed successfully
# 2025-01-19 19:37:13,727 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:45:33 MSK)" (scheduled at 2025-01-19 19:37:13.726491+03:00)
# 2025-01-19 19:37:13,734 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:45:33 MSK)" executed successfully
# 2025-01-19 19:45:33,729 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:53:53 MSK)" (scheduled at 2025-01-19 19:45:33.726491+03:00)
# 2025-01-19 19:45:33,734 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 19:53:53 MSK)" executed successfully
# 2025-01-19 19:53:53,730 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:02:13 MSK)" (scheduled at 2025-01-19 19:53:53.726491+03:00)
# 2025-01-19 19:53:53,737 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:02:13 MSK)" executed successfully
# 2025-01-19 20:02:13,730 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:10:33 MSK)" (scheduled at 2025-01-19 20:02:13.726491+03:00)
# 2025-01-19 20:02:13,734 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:10:33 MSK)" executed successfully
# 2025-01-19 20:10:33,747 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:18:53 MSK)" (scheduled at 2025-01-19 20:10:33.726491+03:00)
# 2025-01-19 20:10:33,752 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:18:53 MSK)" executed successfully
# 2025-01-19 20:18:53,732 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:27:13 MSK)" (scheduled at 2025-01-19 20:18:53.726491+03:00)
# 2025-01-19 20:18:53,737 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:27:13 MSK)" executed successfully
# 2025-01-19 20:27:13,732 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:35:33 MSK)" (scheduled at 2025-01-19 20:27:13.726491+03:00)
# 2025-01-19 20:27:13,738 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:35:33 MSK)" executed successfully
# 2025-01-19 20:35:33,730 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:43:53 MSK)" (scheduled at 2025-01-19 20:35:33.726491+03:00)
# 2025-01-19 20:35:33,736 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:43:53 MSK)" executed successfully
# 2025-01-19 20:43:53,728 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:52:13 MSK)" (scheduled at 2025-01-19 20:43:53.726491+03:00)
# 2025-01-19 20:43:53,736 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 20:52:13 MSK)" executed successfully
# 2025-01-19 20:52:13,727 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:00:33 MSK)" (scheduled at 2025-01-19 20:52:13.726491+03:00)
# 2025-01-19 20:52:13,733 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:00:33 MSK)" executed successfully
# 2025-01-19 21:00:33,727 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:08:53 MSK)" (scheduled at 2025-01-19 21:00:33.726491+03:00)
# 2025-01-19 21:00:33,734 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:08:53 MSK)" executed successfully
# 2025-01-19 21:08:53,727 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:17:13 MSK)" (scheduled at 2025-01-19 21:08:53.726491+03:00)
# 2025-01-19 21:08:53,732 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:17:13 MSK)" executed successfully
# 2025-01-19 21:17:13,746 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:25:33 MSK)" (scheduled at 2025-01-19 21:17:13.726491+03:00)
# 2025-01-19 21:17:13,753 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:25:33 MSK)" executed successfully
# 2025-01-19 21:25:33,727 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:33:53 MSK)" (scheduled at 2025-01-19 21:25:33.726491+03:00)
# 2025-01-19 21:25:33,736 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:33:53 MSK)" executed successfully
# 2025-01-19 21:33:53,727 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:42:13 MSK)" (scheduled at 2025-01-19 21:33:53.726491+03:00)
# 2025-01-19 21:33:53,736 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:42:13 MSK)" executed successfully
# 2025-01-19 21:42:13,729 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:50:33 MSK)" (scheduled at 2025-01-19 21:42:13.726491+03:00)
# 2025-01-19 21:42:13,735 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:50:33 MSK)" executed successfully
# 2025-01-19 21:50:33,771 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:58:53 MSK)" (scheduled at 2025-01-19 21:50:33.726491+03:00)
# 2025-01-19 21:50:33,776 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 21:58:53 MSK)" executed successfully
# 2025-01-19 21:58:53,733 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:07:13 MSK)" (scheduled at 2025-01-19 21:58:53.726491+03:00)
# 2025-01-19 21:58:53,741 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:07:13 MSK)" executed successfully
# 2025-01-19 22:07:13,733 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:15:33 MSK)" (scheduled at 2025-01-19 22:07:13.726491+03:00)
# 2025-01-19 22:07:13,738 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:15:33 MSK)" executed successfully
# 2025-01-19 22:15:33,744 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:23:53 MSK)" (scheduled at 2025-01-19 22:15:33.726491+03:00)
# 2025-01-19 22:15:33,753 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:23:53 MSK)" executed successfully
# 2025-01-19 22:23:53,734 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:32:13 MSK)" (scheduled at 2025-01-19 22:23:53.726491+03:00)
# 2025-01-19 22:23:53,742 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:32:13 MSK)" executed successfully
# 2025-01-19 22:32:13,734 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:40:33 MSK)" (scheduled at 2025-01-19 22:32:13.726491+03:00)
# 2025-01-19 22:32:13,744 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:40:33 MSK)" executed successfully
# 2025-01-19 22:40:33,733 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:48:53 MSK)" (scheduled at 2025-01-19 22:40:33.726491+03:00)
# 2025-01-19 22:40:33,736 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:48:53 MSK)" executed successfully
# 2025-01-19 22:48:53,730 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:57:13 MSK)" (scheduled at 2025-01-19 22:48:53.726491+03:00)
# 2025-01-19 22:48:53,735 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 22:57:13 MSK)" executed successfully
# 2025-01-19 22:57:13,734 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:05:33 MSK)" (scheduled at 2025-01-19 22:57:13.726491+03:00)
# 2025-01-19 22:57:13,741 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:05:33 MSK)" executed successfully
# 2025-01-19 23:05:33,734 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:13:53 MSK)" (scheduled at 2025-01-19 23:05:33.726491+03:00)
# 2025-01-19 23:05:33,744 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:13:53 MSK)" executed successfully
# 2025-01-19 23:13:53,734 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:22:13 MSK)" (scheduled at 2025-01-19 23:13:53.726491+03:00)
# 2025-01-19 23:13:53,743 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:22:13 MSK)" executed successfully
# 2025-01-19 23:22:13,728 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:30:33 MSK)" (scheduled at 2025-01-19 23:22:13.726491+03:00)
# 2025-01-19 23:22:13,736 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-19 23:30:33 MSK)" executed successfully
# 2025-01-19 23:52:41,018 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-19 23:52:41,019 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-19 23:52:52,278 - aiogram.dispatcher - INFO - Connection established (tryings = 1, bot id = 5141660175)
# 2025-01-20 01:06:13,127 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 01:06:13,134 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-20 01:42:46,504 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 01:42:46,516 - aiogram.dispatcher - WARNING - Sleep for 1.289999 seconds and try again... (tryings = 1, bot id = 5141660175)
# 2025-01-20 01:42:55,838 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [Connect call failed ('149.154.167.220', 443)]
# 2025-01-20 01:42:55,839 - aiogram.dispatcher - WARNING - Sleep for 1.650668 seconds and try again... (tryings = 2, bot id = 5141660175)
# 2025-01-20 01:43:07,865 - aiogram.dispatcher - INFO - Connection established (tryings = 3, bot id = 5141660175)
# 2025-01-20 01:43:09,787 - apscheduler.executors.default - WARNING - Run time of job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 01:43:53 MSK)" was missed by 0:07:36.061198
# 2025-01-20 01:44:25,001 - apscheduler.executors.default - WARNING - Run time of job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 01:52:13 MSK)" was missed by 0:00:31.275015
# 2025-01-20 06:48:29,249 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 06:48:29,251 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-20 06:48:40,591 - aiogram.dispatcher - INFO - Connection established (tryings = 1, bot id = 5141660175)
# 2025-01-20 13:55:24,654 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 13:55:24,655 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-20 14:06:06,917 - aiogram.dispatcher - INFO - Connection established (tryings = 1, bot id = 5141660175)
# 2025-01-20 14:37:03,282 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 14:37:03,284 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-20 14:37:04,289 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:37:04,290 - aiogram.dispatcher - WARNING - Sleep for 1.413182 seconds and try again... (tryings = 1, bot id = 5141660175)
# 2025-01-20 14:37:05,713 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:37:05,714 - aiogram.dispatcher - WARNING - Sleep for 1.975486 seconds and try again... (tryings = 2, bot id = 5141660175)
# 2025-01-20 14:37:07,696 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:37:07,697 - aiogram.dispatcher - WARNING - Sleep for 2.680794 seconds and try again... (tryings = 3, bot id = 5141660175)
# 2025-01-20 14:37:51,073 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:37:51,073 - aiogram.dispatcher - WARNING - Sleep for 3.360054 seconds and try again... (tryings = 4, bot id = 5141660175)
# 2025-01-20 14:37:54,441 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:37:54,443 - aiogram.dispatcher - WARNING - Sleep for 4.471353 seconds and try again... (tryings = 5, bot id = 5141660175)
# 2025-01-20 14:37:58,922 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:37:58,923 - aiogram.dispatcher - WARNING - Sleep for 5.020715 seconds and try again... (tryings = 6, bot id = 5141660175)
# 2025-01-20 14:38:03,950 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:38:03,951 - aiogram.dispatcher - WARNING - Sleep for 4.833334 seconds and try again... (tryings = 7, bot id = 5141660175)
# 2025-01-20 14:38:08,791 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:38:08,793 - aiogram.dispatcher - WARNING - Sleep for 5.074398 seconds and try again... (tryings = 8, bot id = 5141660175)
# 2025-01-20 14:38:13,875 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:38:13,876 - aiogram.dispatcher - WARNING - Sleep for 5.067965 seconds and try again... (tryings = 9, bot id = 5141660175)
# 2025-01-20 14:39:56,551 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:39:56,552 - aiogram.dispatcher - WARNING - Sleep for 5.002226 seconds and try again... (tryings = 10, bot id = 5141660175)
# 2025-01-20 14:40:01,558 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:40:01,559 - aiogram.dispatcher - WARNING - Sleep for 5.069146 seconds and try again... (tryings = 11, bot id = 5141660175)
# 2025-01-20 14:40:06,633 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:40:06,634 - aiogram.dispatcher - WARNING - Sleep for 5.044069 seconds and try again... (tryings = 12, bot id = 5141660175)
# 2025-01-20 14:40:11,685 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:40:11,686 - aiogram.dispatcher - WARNING - Sleep for 5.000797 seconds and try again... (tryings = 13, bot id = 5141660175)
# 2025-01-20 14:40:16,694 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:40:16,695 - aiogram.dispatcher - WARNING - Sleep for 5.115630 seconds and try again... (tryings = 14, bot id = 5141660175)
# 2025-01-20 14:40:21,817 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:40:21,819 - aiogram.dispatcher - WARNING - Sleep for 4.974839 seconds and try again... (tryings = 15, bot id = 5141660175)
# 2025-01-20 14:41:18,497 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:41:18,498 - aiogram.dispatcher - WARNING - Sleep for 5.075780 seconds and try again... (tryings = 16, bot id = 5141660175)
# 2025-01-20 14:41:23,580 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:41:23,581 - aiogram.dispatcher - WARNING - Sleep for 5.125152 seconds and try again... (tryings = 17, bot id = 5141660175)
# 2025-01-20 14:41:28,712 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:41:28,713 - aiogram.dispatcher - WARNING - Sleep for 4.915023 seconds and try again... (tryings = 18, bot id = 5141660175)
# 2025-01-20 14:41:33,634 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:41:33,635 - aiogram.dispatcher - WARNING - Sleep for 4.968862 seconds and try again... (tryings = 19, bot id = 5141660175)
# 2025-01-20 14:41:38,610 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:41:38,612 - aiogram.dispatcher - WARNING - Sleep for 5.074730 seconds and try again... (tryings = 20, bot id = 5141660175)
# 2025-01-20 14:41:43,693 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:41:43,694 - aiogram.dispatcher - WARNING - Sleep for 5.041420 seconds and try again... (tryings = 21, bot id = 5141660175)
# 2025-01-20 14:42:29,952 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:42:29,953 - aiogram.dispatcher - WARNING - Sleep for 4.958619 seconds and try again... (tryings = 22, bot id = 5141660175)
# 2025-01-20 14:42:34,918 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:42:34,919 - aiogram.dispatcher - WARNING - Sleep for 5.018423 seconds and try again... (tryings = 23, bot id = 5141660175)
# 2025-01-20 14:42:39,942 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:42:39,943 - aiogram.dispatcher - WARNING - Sleep for 4.938830 seconds and try again... (tryings = 24, bot id = 5141660175)
# 2025-01-20 14:42:44,887 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:42:44,888 - aiogram.dispatcher - WARNING - Sleep for 4.923871 seconds and try again... (tryings = 25, bot id = 5141660175)
# 2025-01-20 14:42:45,438 - apscheduler.executors.default - WARNING - Run time of job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 14:47:13 MSK)" was missed by 0:03:51.712079
# 2025-01-20 14:42:49,819 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:42:49,820 - aiogram.dispatcher - WARNING - Sleep for 5.107220 seconds and try again... (tryings = 26, bot id = 5141660175)
# 2025-01-20 14:43:39,983 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:43:39,984 - aiogram.dispatcher - WARNING - Sleep for 5.048704 seconds and try again... (tryings = 27, bot id = 5141660175)
# 2025-01-20 14:43:45,038 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:43:45,039 - aiogram.dispatcher - WARNING - Sleep for 4.913011 seconds and try again... (tryings = 28, bot id = 5141660175)
# 2025-01-20 14:43:49,958 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:43:49,959 - aiogram.dispatcher - WARNING - Sleep for 4.912549 seconds and try again... (tryings = 29, bot id = 5141660175)
# 2025-01-20 14:43:54,879 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:43:54,880 - aiogram.dispatcher - WARNING - Sleep for 4.928415 seconds and try again... (tryings = 30, bot id = 5141660175)
# 2025-01-20 14:43:59,816 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:43:59,817 - aiogram.dispatcher - WARNING - Sleep for 5.070180 seconds and try again... (tryings = 31, bot id = 5141660175)
# 2025-01-20 14:44:04,894 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:44:04,895 - aiogram.dispatcher - WARNING - Sleep for 4.977811 seconds and try again... (tryings = 32, bot id = 5141660175)
# 2025-01-20 14:45:03,382 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:45:03,383 - aiogram.dispatcher - WARNING - Sleep for 5.066715 seconds and try again... (tryings = 33, bot id = 5141660175)
# 2025-01-20 14:45:08,458 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:45:08,460 - aiogram.dispatcher - WARNING - Sleep for 4.852644 seconds and try again... (tryings = 34, bot id = 5141660175)
# 2025-01-20 14:45:13,319 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:45:13,321 - aiogram.dispatcher - WARNING - Sleep for 5.007138 seconds and try again... (tryings = 35, bot id = 5141660175)
# 2025-01-20 14:45:18,334 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:45:18,335 - aiogram.dispatcher - WARNING - Sleep for 5.101540 seconds and try again... (tryings = 36, bot id = 5141660175)
# 2025-01-20 14:45:23,442 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:45:23,443 - aiogram.dispatcher - WARNING - Sleep for 4.766833 seconds and try again... (tryings = 37, bot id = 5141660175)
# 2025-01-20 14:45:28,217 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:45:28,218 - aiogram.dispatcher - WARNING - Sleep for 5.128417 seconds and try again... (tryings = 38, bot id = 5141660175)
# 2025-01-20 14:46:25,077 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:46:25,077 - aiogram.dispatcher - WARNING - Sleep for 4.910805 seconds and try again... (tryings = 39, bot id = 5141660175)
# 2025-01-20 14:46:29,994 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:46:29,995 - aiogram.dispatcher - WARNING - Sleep for 4.981572 seconds and try again... (tryings = 40, bot id = 5141660175)
# 2025-01-20 14:46:34,982 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:46:34,983 - aiogram.dispatcher - WARNING - Sleep for 4.859080 seconds and try again... (tryings = 41, bot id = 5141660175)
# 2025-01-20 14:46:39,848 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:46:39,849 - aiogram.dispatcher - WARNING - Sleep for 4.898283 seconds and try again... (tryings = 42, bot id = 5141660175)
# 2025-01-20 14:46:44,753 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:46:44,754 - aiogram.dispatcher - WARNING - Sleep for 5.106386 seconds and try again... (tryings = 43, bot id = 5141660175)
# 2025-01-20 14:46:49,866 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:46:49,867 - aiogram.dispatcher - WARNING - Sleep for 5.081813 seconds and try again... (tryings = 44, bot id = 5141660175)
# 2025-01-20 14:47:38,747 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:47:38,748 - aiogram.dispatcher - WARNING - Sleep for 4.957318 seconds and try again... (tryings = 45, bot id = 5141660175)
# 2025-01-20 14:47:43,713 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:47:43,714 - aiogram.dispatcher - WARNING - Sleep for 5.038126 seconds and try again... (tryings = 46, bot id = 5141660175)
# 2025-01-20 14:47:48,760 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:47:48,760 - aiogram.dispatcher - WARNING - Sleep for 5.061578 seconds and try again... (tryings = 47, bot id = 5141660175)
# 2025-01-20 14:47:53,828 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:47:53,829 - aiogram.dispatcher - WARNING - Sleep for 5.191759 seconds and try again... (tryings = 48, bot id = 5141660175)
# 2025-01-20 14:47:59,027 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:47:59,028 - aiogram.dispatcher - WARNING - Sleep for 5.027574 seconds and try again... (tryings = 49, bot id = 5141660175)
# 2025-01-20 14:48:55,112 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:48:55,113 - aiogram.dispatcher - WARNING - Sleep for 4.880303 seconds and try again... (tryings = 50, bot id = 5141660175)
# 2025-01-20 14:49:00,002 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:49:00,005 - aiogram.dispatcher - WARNING - Sleep for 4.837762 seconds and try again... (tryings = 51, bot id = 5141660175)
# 2025-01-20 14:49:04,851 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:49:04,852 - aiogram.dispatcher - WARNING - Sleep for 4.976524 seconds and try again... (tryings = 52, bot id = 5141660175)
# 2025-01-20 14:56:25,000 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 14:56:25,001 - aiogram.dispatcher - WARNING - Sleep for 4.995132 seconds and try again... (tryings = 53, bot id = 5141660175)
# 2025-01-20 15:42:33,864 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 15:42:33,865 - aiogram.dispatcher - WARNING - Sleep for 5.010965 seconds and try again... (tryings = 54, bot id = 5141660175)
# 2025-01-20 15:42:59,231 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:42:59,233 - aiogram.dispatcher - WARNING - Sleep for 5.085098 seconds and try again... (tryings = 55, bot id = 5141660175)
# 2025-01-20 15:43:04,326 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:04,327 - aiogram.dispatcher - WARNING - Sleep for 5.036208 seconds and try again... (tryings = 56, bot id = 5141660175)
# 2025-01-20 15:43:09,370 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:09,371 - aiogram.dispatcher - WARNING - Sleep for 5.219123 seconds and try again... (tryings = 57, bot id = 5141660175)
# 2025-01-20 15:43:14,600 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:14,602 - aiogram.dispatcher - WARNING - Sleep for 4.896825 seconds and try again... (tryings = 58, bot id = 5141660175)
# 2025-01-20 15:43:19,503 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:19,504 - aiogram.dispatcher - WARNING - Sleep for 4.898537 seconds and try again... (tryings = 59, bot id = 5141660175)
# 2025-01-20 15:43:24,408 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:24,411 - aiogram.dispatcher - WARNING - Sleep for 5.004910 seconds and try again... (tryings = 60, bot id = 5141660175)
# 2025-01-20 15:43:27,113 - apscheduler.executors.default - WARNING - Run time of job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 15:45:33 MSK)" was missed by 0:06:13.387283
# 2025-01-20 15:43:29,421 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:29,422 - aiogram.dispatcher - WARNING - Sleep for 5.163099 seconds and try again... (tryings = 61, bot id = 5141660175)
# 2025-01-20 15:43:34,592 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:34,593 - aiogram.dispatcher - WARNING - Sleep for 4.964747 seconds and try again... (tryings = 62, bot id = 5141660175)
# 2025-01-20 15:43:39,564 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:39,565 - aiogram.dispatcher - WARNING - Sleep for 4.915016 seconds and try again... (tryings = 63, bot id = 5141660175)
# 2025-01-20 15:43:44,487 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:44,488 - aiogram.dispatcher - WARNING - Sleep for 5.113702 seconds and try again... (tryings = 64, bot id = 5141660175)
# 2025-01-20 15:43:49,608 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:49,609 - aiogram.dispatcher - WARNING - Sleep for 5.191602 seconds and try again... (tryings = 65, bot id = 5141660175)
# 2025-01-20 15:43:54,805 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:54,806 - aiogram.dispatcher - WARNING - Sleep for 4.898149 seconds and try again... (tryings = 66, bot id = 5141660175)
# 2025-01-20 15:43:59,711 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:43:59,712 - aiogram.dispatcher - WARNING - Sleep for 4.968967 seconds and try again... (tryings = 67, bot id = 5141660175)
# 2025-01-20 15:44:04,687 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:04,688 - aiogram.dispatcher - WARNING - Sleep for 4.917619 seconds and try again... (tryings = 68, bot id = 5141660175)
# 2025-01-20 15:44:09,612 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:09,613 - aiogram.dispatcher - WARNING - Sleep for 4.929371 seconds and try again... (tryings = 69, bot id = 5141660175)
# 2025-01-20 15:44:14,548 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:14,549 - aiogram.dispatcher - WARNING - Sleep for 5.130329 seconds and try again... (tryings = 70, bot id = 5141660175)
# 2025-01-20 15:44:19,686 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:19,687 - aiogram.dispatcher - WARNING - Sleep for 5.073277 seconds and try again... (tryings = 71, bot id = 5141660175)
# 2025-01-20 15:44:24,766 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:24,767 - aiogram.dispatcher - WARNING - Sleep for 5.040257 seconds and try again... (tryings = 72, bot id = 5141660175)
# 2025-01-20 15:44:29,814 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:29,815 - aiogram.dispatcher - WARNING - Sleep for 5.082721 seconds and try again... (tryings = 73, bot id = 5141660175)
# 2025-01-20 15:44:34,904 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:34,905 - aiogram.dispatcher - WARNING - Sleep for 5.069070 seconds and try again... (tryings = 74, bot id = 5141660175)
# 2025-01-20 15:44:39,982 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:39,983 - aiogram.dispatcher - WARNING - Sleep for 5.155340 seconds and try again... (tryings = 75, bot id = 5141660175)
# 2025-01-20 15:44:45,147 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:45,148 - aiogram.dispatcher - WARNING - Sleep for 4.938992 seconds and try again... (tryings = 76, bot id = 5141660175)
# 2025-01-20 15:44:50,093 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:50,094 - aiogram.dispatcher - WARNING - Sleep for 5.014776 seconds and try again... (tryings = 77, bot id = 5141660175)
# 2025-01-20 15:44:55,114 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:44:55,115 - aiogram.dispatcher - WARNING - Sleep for 5.002092 seconds and try again... (tryings = 78, bot id = 5141660175)
# 2025-01-20 15:45:00,124 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:45:00,125 - aiogram.dispatcher - WARNING - Sleep for 4.864877 seconds and try again... (tryings = 79, bot id = 5141660175)
# 2025-01-20 15:45:04,994 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:45:04,995 - aiogram.dispatcher - WARNING - Sleep for 5.065512 seconds and try again... (tryings = 80, bot id = 5141660175)
# 2025-01-20 15:45:10,067 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:45:10,068 - aiogram.dispatcher - WARNING - Sleep for 4.912289 seconds and try again... (tryings = 81, bot id = 5141660175)
# 2025-01-20 15:46:04,888 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 15:46:04,889 - aiogram.dispatcher - WARNING - Sleep for 4.887905 seconds and try again... (tryings = 82, bot id = 5141660175)
# 2025-01-20 15:46:19,967 - aiogram.dispatcher - INFO - Connection established (tryings = 83, bot id = 5141660175)
# 2025-01-20 15:46:23,629 - apscheduler.executors.default - WARNING - Run time of job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 15:53:53 MSK)" was missed by 0:00:49.903350
# 2025-01-20 16:20:33,673 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 16:20:33,674 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-20 16:20:34,681 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:20:34,682 - aiogram.dispatcher - WARNING - Sleep for 1.371463 seconds and try again... (tryings = 1, bot id = 5141660175)
# 2025-01-20 16:20:36,061 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:20:36,062 - aiogram.dispatcher - WARNING - Sleep for 1.635988 seconds and try again... (tryings = 2, bot id = 5141660175)
# 2025-01-20 16:20:37,715 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:20:37,715 - aiogram.dispatcher - WARNING - Sleep for 2.036346 seconds and try again... (tryings = 3, bot id = 5141660175)
# 2025-01-20 16:20:39,757 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:20:39,758 - aiogram.dispatcher - WARNING - Sleep for 2.718916 seconds and try again... (tryings = 4, bot id = 5141660175)
# 2025-01-20 16:23:26,399 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 16:23:26,401 - aiogram.dispatcher - WARNING - Sleep for 3.549560 seconds and try again... (tryings = 5, bot id = 5141660175)
# 2025-01-20 16:23:29,957 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:23:29,958 - aiogram.dispatcher - WARNING - Sleep for 4.606704 seconds and try again... (tryings = 6, bot id = 5141660175)
# 2025-01-20 16:24:14,568 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:24:14,569 - aiogram.dispatcher - WARNING - Sleep for 5.024984 seconds and try again... (tryings = 7, bot id = 5141660175)
# 2025-01-20 16:24:19,600 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:24:19,601 - aiogram.dispatcher - WARNING - Sleep for 4.963379 seconds and try again... (tryings = 8, bot id = 5141660175)
# 2025-01-20 16:24:24,570 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:24:24,570 - aiogram.dispatcher - WARNING - Sleep for 5.047541 seconds and try again... (tryings = 9, bot id = 5141660175)
# 2025-01-20 16:24:29,625 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:24:29,626 - aiogram.dispatcher - WARNING - Sleep for 5.013167 seconds and try again... (tryings = 10, bot id = 5141660175)
# 2025-01-20 16:24:34,647 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:24:34,648 - aiogram.dispatcher - WARNING - Sleep for 5.062084 seconds and try again... (tryings = 11, bot id = 5141660175)
# 2025-01-20 16:24:39,715 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:24:39,716 - aiogram.dispatcher - WARNING - Sleep for 4.804842 seconds and try again... (tryings = 12, bot id = 5141660175)
# 2025-01-20 16:25:27,572 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:25:27,573 - aiogram.dispatcher - WARNING - Sleep for 5.005771 seconds and try again... (tryings = 13, bot id = 5141660175)
# 2025-01-20 16:25:32,584 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:25:32,585 - aiogram.dispatcher - WARNING - Sleep for 5.091168 seconds and try again... (tryings = 14, bot id = 5141660175)
# 2025-01-20 16:25:37,683 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:25:37,683 - aiogram.dispatcher - WARNING - Sleep for 4.977054 seconds and try again... (tryings = 15, bot id = 5141660175)
# 2025-01-20 16:25:42,669 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:25:42,670 - aiogram.dispatcher - WARNING - Sleep for 5.068479 seconds and try again... (tryings = 16, bot id = 5141660175)
# 2025-01-20 16:25:47,749 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - ClientConnectorError: Cannot connect to host api.telegram.org:443 ssl:default [nodename nor servname provided, or not known]
# 2025-01-20 16:25:47,750 - aiogram.dispatcher - WARNING - Sleep for 5.021351 seconds and try again... (tryings = 17, bot id = 5141660175)
# 2025-01-20 16:26:04,106 - aiogram.dispatcher - INFO - Connection established (tryings = 18, bot id = 5141660175)
# 2025-01-20 16:27:24,439 - aiogram.dispatcher - ERROR - Failed to fetch updates - TelegramNetworkError: HTTP Client says - Request timeout error
# 2025-01-20 16:27:24,441 - aiogram.dispatcher - WARNING - Sleep for 1.000000 seconds and try again... (tryings = 0, bot id = 5141660175)
# 2025-01-20 16:27:35,640 - aiogram.dispatcher - INFO - Connection established (tryings = 1, bot id = 5141660175)
# 2025-01-20 16:29:43,402 - apscheduler.executors.default - WARNING - Run time of job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 16:35:33 MSK)" was missed by 0:02:29.675640
# 2025-01-20 16:35:33,728 - apscheduler.executors.default - INFO - Running job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 16:43:53 MSK)" (scheduled at 2025-01-20 16:35:33.726491+03:00)
# 2025-01-20 16:35:33,735 - apscheduler.executors.default - INFO - Job "send_msg (trigger: interval[0:08:20], next run at: 2025-01-20 16:43:53 MSK)" executed successfully
# 2025-01-20 16:38:31,087 - aiogram.event - INFO - Update id=708829275 is handled. Duration 250 ms by bot id=5141660175
# 2025-01-20 16:38:33,717 - aiogram.event - INFO - Update id=708829276 is handled. Duration 165 ms by bot id=5141660175
# nikita0607
# 2025-01-20 16:42:11,632 - aiogram.dispatcher - WARNING - Received SIGINT signal
# 2025-01-20 16:42:11,643 - aiogram.dispatcher - INFO - Polling stopped for bot @TestOGE8_bot id=5141660175 - 'PokemonStrategy'
# 2025-01-20 16:42:11,644 - aiogram.dispatcher - INFO - Polling stopped
# 2025-01-20 16:42:11,897 - apscheduler.scheduler - INFO - Removed job da353f7c2b1c43ec91bb21caa3614bd3
# Бот остановлен
